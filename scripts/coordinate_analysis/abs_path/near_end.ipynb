# %%
import pandas as pd
import glob
import sys
import os

# %%
accession="GCA_000001405.29"
threshold_short=1000000
threshold_ends=0.1

# %%
new_directory = f"/lab/wengpj01/vertebrate_pipeline/subdirs/{accession}"
os.chdir(new_directory)

# %%
# Read chromsizes.csv into a pandas dataframe
chromsizes = pd.read_csv('chromsizes.csv', sep='\t', header=None, names=['chr', 'length'])

# Find and read all *_from_pipeline.gtf files into a list of dataframes
gtf_files = glob.glob('*_from_pipeline.gtf')
gene_dfs = []

for gtf_file in gtf_files:
    df = pd.read_csv(gtf_file, sep='\t', header=None, names=['seqname', 'source', 'feature', 'start', 'end', 'score', 'strand', 'frame', 'attribute'])
    gene_dfs.append(df)
    
    # Strip text before the last underscore in the 'seqname' column
    df['seqname'] = df['seqname'].str.replace(r'^.*_', '', regex=True)

# Concatenate all dataframes into a single dataframe
genes = pd.concat(gene_dfs, ignore_index=True)

# %%
# Iterate through rows of the 'genes' dataframe and find corresponding chromosome length
genes['chr_length'] = None  # Create an empty column to store chromosome lengths
genes['chr_mini'] = None
genes['ends'] = None

for i, gene_row in genes.iterrows():
    seqname = gene_row['seqname']
    
    # Find the corresponding row in 'chromsizes'
    chrom_row = chromsizes[chromsizes['chr'] == seqname]
    
    if not chrom_row.empty:
        chr_length = chrom_row.iloc[0]['length']
        genes.at[i, 'chr_length'] = chr_length
        
        to_end = (chr_length - gene_row["start"])/chr_length
        to_start = (gene_row["start"])/chr_length
        
        if (to_start < threshold_ends) or (to_end < threshold_ends):
            genes.at[i, 'ends'] = "True"
        else:
            genes.at[i, 'ends'] = "False"
        
        if chr_length < threshold_short:
            genes.at[i, 'chr_mini'] = "True"
        else:
            genes.at[i, 'chr_mini'] = "False"

# %%
# Calculate the fraction of rows where 'chr_mini' is True
fraction_chr_mini_true = len(genes[genes['chr_mini'] == "True"]) / len(genes)
print(fraction_chr_mini_true)
# Out:
# 0.5333333333333333

# %%
# Calculate the fraction of rows where 'ends' is True
fraction_near_ends = len(genes[genes['ends'] == "True"]) / len(genes)
print(fraction_near_ends)
# Out:
# 0.3333333333333333

# %%
# Calculate the fraction of rows where 'ends' is True and 'chr_mini' is False
fraction_near_ends_long = len(genes[(genes['ends'] == "True") & (genes['chr_mini'] == "False")]) / len(genes[genes['chr_mini'] == "False"])
print(fraction_near_ends_long)
# Out:
# 0.5

# %%
genes
# Out:
#        seqname  source feature      start        end score strand  frame  \
# 0   CM000667.2  Genome    exon    9629133    9630032     .      -      0
# 1   CM000669.2  Genome    exon  122994759  122995634     .      -      0
# 2   CM000669.2  Genome    exon  141764159  141765109     .      +      0
# 3   CM000669.2  Genome    exon  141778489  141779388     .      +      0
# 4   CM000669.2  Genome    exon  141790101  141791261     .      +      0
# 5   CM000669.2  Genome    exon  141972688  141973689     .      -      0
# 6   CM000669.2  Genome    exon  143183419  143184435     .      +      0
# 7   CM000669.2  Genome    exon  143222079  143223050     .      +      0
# 8   CM000674.2  Genome    exon   10806051   10806980     .      -      0
# 9   CM000674.2  Genome    exon   10938254   10939222     .      -      0
# 10  CM000674.2  Genome    exon   10996946   10997875     .      -      0
# 11  CM000674.2  Genome    exon   11061365   11062294     .      -      0
# 12  CM000674.2  Genome    exon   11091300   11092478     .      -      0
# 13  CM000674.2  Genome    exon   11185993   11186937     .      -      0
# 14  GL877876.1  Genome    exon     107093     108004     .      -      0
# 15  GL877876.1  Genome    exon     220378     221334     .      -      0
# 16  GL877876.1  Genome    exon     229112     230041     .      -      0
# 17  GL877876.1  Genome    exon     290027     291205     .      -      0
# 18  GL877876.1  Genome    exon        320       1276     .      -      0
# 19  GL877876.1  Genome    exon     363939     364898     .      -      0
# 20  KI270904.1  Genome    exon     184654     185553     .      -      0
# 21  KI270904.1  Genome    exon     195641     196570     .      -      0
# 22  KI270904.1  Genome    exon     220366     221322     .      -      0
# 23  KI270904.1  Genome    exon     229411     230340     .      -      0
# 24  KI270904.1  Genome    exon      24052      24975     .      -      0
# 25  KI270904.1  Genome    exon     291887     292786     .      -      0
# 26  KI270904.1  Genome    exon     328319     329278     .      -      0
# 27  KI270904.1  Genome    exon       7843       8781     .      -      0
# 28  KZ208912.1  Genome    exon      62817      63773     .      +      0
# 29  KZ208912.1  Genome    exon      97237      98160     .      +      0
#
#                                        attribute chr_length chr_mini   ends
# 0     gene_id "KH9511"; transcript_id "KH9511.1"  181538259    False   True
# 1     gene_id "KH8006"; transcript_id "KH8006.1"  159345973    False  False
# 2     gene_id "KH3992"; transcript_id "KH3992.1"  159345973    False  False
# 3     gene_id "KH3483"; transcript_id "KH3483.1"  159345973    False  False
# 4     gene_id "KH5175"; transcript_id "KH5175.1"  159345973    False  False
# 5     gene_id "KH3818"; transcript_id "KH3818.1"  159345973    False  False
# 6   gene_id "KH11253"; transcript_id "KH11253.1"  159345973    False  False
# 7     gene_id "KH2887"; transcript_id "KH2887.1"  159345973    False  False
# 8     gene_id "KH1732"; transcript_id "KH1732.1"  133275309    False   True
# 9   gene_id "KH11772"; transcript_id "KH11772.1"  133275309    False   True
# 10    gene_id "KH1646"; transcript_id "KH1646.1"  133275309    False   True
# 11    gene_id "KH5043"; transcript_id "KH5043.1"  133275309    False   True
# 12    gene_id "KH8136"; transcript_id "KH8136.1"  133275309    False   True
# 13    gene_id "KH8534"; transcript_id "KH8534.1"  133275309    False   True
# 14    gene_id "KH7083"; transcript_id "KH7083.1"     408271     True  False
# 15  gene_id "KH10927"; transcript_id "KH10927.1"     408271     True  False
# 16    gene_id "KH5582"; transcript_id "KH5582.1"     408271     True  False
# 17    gene_id "KH8438"; transcript_id "KH8438.1"     408271     True  False
# 18      gene_id "KH901"; transcript_id "KH901.1"     408271     True   True
# 19    gene_id "KH6198"; transcript_id "KH6198.1"     408271     True  False
# 20    gene_id "KH7855"; transcript_id "KH7855.1"     572349     True  False
# 21          gene_id "KH1"; transcript_id "KH1.1"     572349     True  False
# 22  gene_id "KH10727"; transcript_id "KH10727.1"     572349     True  False
# 23    gene_id "KH7248"; transcript_id "KH7248.1"     572349     True  False
# 24    gene_id "KH4204"; transcript_id "KH4204.1"     572349     True   True
# 25      gene_id "KH348"; transcript_id "KH348.1"     572349     True  False
# 26    gene_id "KH6402"; transcript_id "KH6402.1"     572349     True  False
# 27    gene_id "KH9144"; transcript_id "KH9144.1"     572349     True   True
# 28    gene_id "KH3324"; transcript_id "KH3324.1"     589656     True  False
# 29    gene_id "KH2737"; transcript_id "KH2737.1"     589656     True  False
